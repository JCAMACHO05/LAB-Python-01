# %%
edad = int(input("Edad: "))
licencia = input("¿Licencia? (s/n): ")
sancionado = input("¿Está sancionado? (s/n): ")

if edad >= 18 and licencia == "s" and sancionado == "n":
    print("Puede conducir")
else:
    print("No puede conducir")

# %%
n = int(input("Ingrese n: "))
suma = 0

for i in range(1, n+1):
    if i % 2 == 0:
        print("Par:", i)
    suma += i

print("Suma total:", suma)

# %%
temperaturas = [22.5, 23.0, 21.8, 24.3, 25.1]

# Agregar
temperaturas.append(23.7)

# Eliminar primera
temperaturas.pop(0)

# Insertar en segunda posición
temperaturas.insert(1, 22.8)

# Ordenar
ordenadas = sorted(temperaturas)

# Cálculos
max_temp = max(temperaturas)
min_temp = min(temperaturas)
diferencia = max_temp - min_temp
promedio = sum(temperaturas) / len(temperaturas)

# Índice
indice = temperaturas.index(23.7)

# Sublistas
sublista = temperaturas[1:4]
primeras = temperaturas[:3]

print("Ordenadas:", ordenadas)
print("Diferencia:", diferencia)
print("Promedio:", promedio)
print("Índice de 23.7:", indice)
print("Pos 2 a 4:", sublista)
print("Primeras 3:", primeras)
promedio = sum(temperaturas) / len(temperaturas)

mayores = [t for t in temperaturas if t > promedio]
print("Mayores al promedio:", mayores)

# %%
contador = 5
while contador > 0:
    print(contador)
    contador -= 1

# %%
while True:
    num = int(input("Número (0 para salir): "))
    if num == 0:
        break

# %%
suma_pares = 0
suma_impares = 0

for i in range(1, 11):
    if i % 2 == 0:
        suma_pares += i
    else:
        suma_impares += i

estado = {
    "pares": suma_pares,
    "impares": suma_impares
}

print(estado)

# %%
productos = []

while True:
    nombre = input("Producto (fin para salir): ")
    if nombre == "fin":
        break

    try:
        precio = float(input("Precio: "))
        cantidad = int(input("Cantidad: "))
    except ValueError:
        print("Entrada inválida")
        continue

    if precio < 0 or cantidad < 0:
        print("Valores negativos no permitidos")
        continue

    productos.append({"nombre": nombre, "precio": precio, "cantidad": cantidad})

# Total
total = sum(p["precio"] * p["cantidad"] for p in productos)

print("Total:", total)

if productos:
    caro = max(productos, key=lambda x: x["precio"])
    print("Más caro:", caro)
else:
    print("No hay productos")

print("Estado final:", productos)
